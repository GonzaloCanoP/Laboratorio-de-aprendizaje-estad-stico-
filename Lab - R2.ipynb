# %% [markdown]
# # Laboratorio de regresión - 2

# %% [markdown]
# |                |                      |
# :----------------|----------------------|
# | **Nombre**     | Gonzalo Cano Padilla |
# | **Fecha**      | 26 de agosto 2025    |
# | **Expediente** | 745901               |

# %% [markdown]
# ## Regresión polinomial

# %% [markdown]
# Observa la siguiente gráfica.

# %%
import matplotlib.pyplot as plt; import numpy as np
# %matplotlib inline
np.random.seed(0)
x = np.linspace(-3, 3, 100); y = 1 + 4*x**2 + np.random.normal(0, 1, 100)
plt.figure(); plt.xlabel("x"); plt.ylabel("y")
plt.scatter(x, y); plt.grid()
plt.show()

# %% [markdown]
# Utiliza `sklearn` para realizar una regresión lineal simple ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x $)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
x = np.linspace(-3, 3, 100)
y = 1 + 4*x**2 + np.random.normal(0, 1, 100)
X=x.reshape(-1,1)
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
print("B0",lr.intercept_)
print("B1",lr.coef_)
# Out:
# B0 13.183191981864576
# B1 [0.04860316]

# %% [markdown]
# Crea una gráfica donde se muestren las observaciones como una nube de puntos y la línea que ajustaste con regresión. Calcula el métrico $R^2$.

# %%
y_pred = lr.predict(X)

plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# -0.0002790896043065594

# %% [markdown]
# Podemos ver que el ajuste no es correcto, pues parece que tiene un comportamiento cuadrático y estamos intentando ajustar una línea recta.
#
# En lugar de hacer una regresión lineal simple, quizás podamos extender el modelo para que tenga varios factores dentro:
#
# $$ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + ... + \beta_p X^p + \epsilon$$

# %% [markdown]
# Ajusta un modelo cuadrático con `sklearn` ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x + \hat{\beta_1}x^2 $) y calcula su $R^2$.

# %%
from sklearn.preprocessing import PolynomialFeatures
x = np.linspace(-3, 3, 100)
y = 1 + 4*x**2 + np.random.normal(0, 1, 100)
X=x.reshape(-1,1)

poly=PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(X)

lr.fit(X_poly,y)

# %%
y_pred = lr.predict(X_poly)

# %%
r2_score(y, y_pred)
# Out:
# 0.9930791905832561

# %% [markdown]
# Crea una gráfica con las observaciones y la nueva curva que ajustaste.

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color ='red')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# Ajusta modelos de grados 3, 5, 7, 9, y 11. Calcula su $R^2$.

# %%
# Modelo grado 3
poly=PolynomialFeatures(degree=3)
X_poly=poly.fit_transform(X)

lr.fit(X_poly,y)
y_pred = lr.predict(X_poly)

# %%
R2 = r2_score(y, y_pred)
B0 = lr.intercept_
Coeficientes= lr.coef_
print(f"R2={R2}")
print(f"B0={B0}")
print(f"Coeficientes={Coeficientes}")
# Out:
# R2=0.9930797770856418
# B0=0.7318080606045534
# Coeficientes=[0.00000000e+00 3.73904608e-02 4.06827395e+00 2.03557932e-03]

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color ='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Modelo grado 3')
plt.grid(True)
plt.show()

# %%
# Modelo grado 5
poly=PolynomialFeatures(degree=5)
X_poly=poly.fit_transform(X)

lr.fit(X_poly,y)
y_pred = lr.predict(X_poly)

R2 = r2_score(y, y_pred)
B0 = lr.intercept_
Coeficientes= lr.coef_
print(f"R2={R2}")
print(f"B0={B0}")
print(f"Coeficientes={Coeficientes}")
# Out:
# R2=0.9931616525278834
# B0=0.6462822516277296
# Coeficientes=[ 0.         -0.09966602  4.16146438  0.0717458  -0.01184498 -0.00683708]

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color ='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Modelo grado 5')
plt.grid(True)
plt.show()

# %%
# Modelo grado 7
poly=PolynomialFeatures(degree=7)
X_poly=poly.fit_transform(X)

lr.fit(X_poly,y)
y_pred = lr.predict(X_poly)

R2 = r2_score(y, y_pred)
B0 = lr.intercept_
Coeficientes= lr.coef_
print(f"R2={R2}")
print(f"B0={B0}")
print(f"Coeficientes={Coeficientes}")
# Out:
# R2=0.9932023714411927
# B0=0.7101399342787484
# Coeficientes=[ 0.00000000e+00 -2.21137382e-01  4.01523802e+00  1.91002797e-01
#   3.59830021e-02 -3.54535340e-02 -3.82349333e-03  1.93192660e-03]

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color ='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Modelo grado 7')
plt.grid(True)
plt.show()

# %%
# Modelo grado 11
poly=PolynomialFeatures(degree=11)
X_poly=poly.fit_transform(X)

lr.fit(X_poly,y)
y_pred = lr.predict(X_poly)

R2 = r2_score(y, y_pred)
B0 = lr.intercept_
Coeficientes= lr.coef_
print(f"R2={R2}")
print(f"B0={B0}")
print(f"Coeficientes={Coeficientes}")
# Out:
# R2=0.9932964951945427
# B0=0.8252769004952807
# Coeficientes=[ 0.00000000e+00 -6.31996331e-01  3.47516970e+00  1.09530255e+00
#   4.47934369e-01 -5.95498516e-01 -1.14972798e-01  1.43898359e-01
#   1.23268983e-02 -1.57692579e-02 -4.80684443e-04  6.37475448e-04]

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color ='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Modelo grado 11')
plt.grid(True)
plt.show()

# %% [markdown]
# **¿Cuál modelo consideras que es mejor? ¿Por qué?**
# - Yo considero que el modelo de grado 3 o 5 pueden ser los mejores ya que conforme vamos subiendo el grado a veces se puede presentar un sobreajuste y como todas las $ R^2 $ son muy parecidas considero que nos podemos ir con un modelo más simple como los de grado 3 o 5

# %% [markdown]
# Recuerda que una de las metas de ajustar modelos es para poder interpolar y extrapolar. Los datos que tenemos mantienen $x \in [-3, 3]$. ¿Qué pasaría si quisiéramos saber el valor de $y$ cuando $x=5$?
#
# Calcula la predicción $\hat{y}$ para todos los modelos creados (grados 2, 3, 5, 7, 9, y 11).

# %%
grados=[2,3,5,7,9,11]
x_new = np.array([[5]])

# Diccionario para guardar predicciones
predicciones = {}

for g in grados:
    poly = PolynomialFeatures(degree=g)
    X_poly = poly.fit_transform(X)

    lr = LinearRegression()
    lr.fit(X_poly, y)

    # Predicción cuando x=5
    x_new_poly = poly.transform(x_new)
    y_pred_new = lr.predict(x_new_poly)

    # Resultados
    predicciones[g] = y_pred_new[0]
    print(f"Grado {g}: Predicción cuando x=5 -> {y_pred_new[0]}")
# Out:
# Grado 2: Predicción cuando x=5 -> 102.68167270715247
# Grado 3: Predicción cuando x=5 -> 102.88005664148311
# Grado 5: Predicción cuando x=5 -> 84.38378709272929
# Grado 7: Predicción cuando x=5 -> 126.74751805265572
# Grado 9: Predicción cuando x=5 -> 70.9879751200237
# Grado 11: Predicción cuando x=5 -> 8534.502509255859

# %% [markdown]
# ¿Cuál modelo crees que sea mejor?
# - Yo considero que el modelo de grado 2 o 3 serian los mejores, ya que son los que tienen una predicción bastante aceptable y nada fuera del rango, pero si vemos que conforme va subiendo el rango, las predicciones son menos acertadas y un poco fuera de lo normal y se puede ver un sobreajuste

# %% [markdown]
# ## Referencia
#
# James, G., Witten, D., Hastie, T., Tibshirani, R.,, Taylor, J. (2023). An Introduction to Statistical Learning with Applications in Python. Cham: Springer. ISBN: 978-3-031-38746-3

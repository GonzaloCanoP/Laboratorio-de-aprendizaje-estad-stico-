# %% [markdown]
# # Factores cualitativos

# %%
import pandas as pd
import numpy as np

datos = pd.read_excel('aguas_feo.xlsx')
datos
# Out:
#     K  C  H  M  Tamaño  Hielo  Calificación
# 0   1  0  0  0       0      1           9.0
# 1   1  0  0  0       0      0           7.0
# 2   1  0  0  0       1      1          10.0
# 3   1  0  0  0       1      0           8.0
# 4   0  1  0  0       0      1           8.0
# 5   0  1  0  0       0      0           6.0
# 6   0  1  0  0       1      1          10.0
# 7   0  1  0  0       1      0           7.0
# 8   0  0  1  0       0      1           8.0
# 9   0  0  1  0       0      0           6.0
# 10  0  0  1  0       1      1           9.5
# 11  0  0  1  0       1      0           7.0
# 12  0  0  0  1       0      1           9.0
# 13  0  0  0  1       0      0           7.0
# 14  0  0  0  1       1      1          10.0
# 15  0  0  0  1       1      0           8.0

# %%
import statsmodels.api as sm
n=len(datos)
y = datos['Calificación']
x = datos.drop(columns=['Calificación'])

unos = np.ones([n,1])
X = np.hstack([unos, x])
ols = sm.OLS(y,X)
results = ols.fit()
results.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Calificación   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     83.67
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):           7.90e-08
# Time:                        17:12:18   Log-Likelihood:                 2.8474
# No. Observations:                  16   AIC:                             6.305
# Df Residuals:                      10   BIC:                             10.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
# Ahora con 1 y -1
datos2=pd.read_excel('aguas_feo1.xlsx')
datos2
# Out:
#     K  C  H  M  Tamaño  Hielo  Calificación
# 0   1  0  0  0      -1      1           9.0
# 1   1  0  0  0      -1     -1           7.0
# 2   1  0  0  0       1      1          10.0
# 3   1  0  0  0       1     -1           8.0
# 4   0  1  0  0      -1      1           8.0
# 5   0  1  0  0      -1     -1           6.0
# 6   0  1  0  0       1      1          10.0
# 7   0  1  0  0       1     -1           7.0
# 8   0  0  1  0      -1      1           8.0
# 9   0  0  1  0      -1     -1           6.0
# 10  0  0  1  0       1      1           9.5
# 11  0  0  1  0       1     -1           7.0
# 12  0  0  0  1      -1      1           9.0
# 13  0  0  0  1      -1     -1           7.0
# 14  0  0  0  1       1      1          10.0
# 15  0  0  0  1       1     -1           8.0

# %%
n=len(datos2)
y = datos2['Calificación']
x = datos2.drop(columns=['Calificación'])

unos = np.ones([n,1])
X = np.hstack([unos, x])
ols = sm.OLS(y,X)
results = ols.fit()
results.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Calificación   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     83.67
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):           7.90e-08
# Time:                        17:12:21   Log-Likelihood:                 2.8474
# No. Observations:                  16   AIC:                             6.305
# Df Residuals:                      10   BIC:                             10.94
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ---
#
# # Ejercicio Motor Trend Car Road Test

# %%
datos_motor = pd.read_excel('Motor Trend Car Road Tests.xlsx')
datos_motor
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
datos_motor.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ## Train

# %%
from sklearn.model_selection import train_test_split
y = datos_motor['mpg']
x = datos_motor.drop(columns=['mpg','model'])

X_train,X_test,y_train,y_test = train_test_split(x,y,train_size=0.4,random_state=137)

# %%
# Escalamiento de Train
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_scaled_train= scaler.transform(X_train)

# %%
# Regresión train
n=len(X_scaled_train)
unos = np.ones([n,1])
X = np.hstack([unos, X_scaled_train])
ols = sm.OLS(y_train,X)
results = ols.fit()
results.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     9.981
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):              0.242
# Time:                        17:40:04   Log-Likelihood:                -9.9811
# No. Observations:                  12   AIC:                             41.96
# Df Residuals:                       1   BIC:                             47.30
# Df Model:                          10
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## Test

# %%
# Escalamiento de test
X_scaled_test = scaler.transform(X_test)

# %%
# Regresión test
n=len(X_scaled_test)
unos = np.ones([n,1])
X = np.hstack([unos, X_scaled_test])
ols = sm.OLS(y_test,X)
results = ols.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     8.231
# Date:                Mon, 08 Sep 2025   Prob (F-statistic):            0.00201
# Time:                        17:40:25   Log-Likelihood:                -39.494
# No. Observations:                  20   AIC:                             101.0
# Df Residuals:                       9   BIC:                             111.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.4166      1.097     15.872      0.000      14.934      19.899
# ...
